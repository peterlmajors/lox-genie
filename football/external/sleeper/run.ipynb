# %% [markdown]
# Get League Rosters with Player Metadata

# %%
import os, sys
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from config import settings
from leagues import *

df = get_league_rosters_metadata(settings.SLEEPER_IFL_25, ['refn', 'FeCurtain'])
df.to_csv('../../data/2025/ifl/sleeper-rosters.csv', index=False)
df.head()
# Out:
#   player_id        full_name position  \
# 0     10236   Dalton Kincaid       TE
# 1      4981    Calvin Ridley       WR
# 2     11625  Adonai Mitchell       WR
# 3     11629  Devontez Walker       WR
# 4      5848  Hollywood Brown       WR
#
#                                             headshot nickname roster_slot  \
# 0                                               None     None     starter
# 1  https://a.espncdn.com/i/headshots/nfl/players/...     None     starter
# 2                                               None     None       bench
# 3                                               None     None       bench
# 4  https://a.espncdn.com/i/headshots/nfl/players/...     None       bench
#
#             team_name
# 0  New Delhi Penguins
# 1  New Delhi Penguins
# 2  New Delhi Penguins
# 3  New Delhi Penguins
# 4  New Delhi Penguins
